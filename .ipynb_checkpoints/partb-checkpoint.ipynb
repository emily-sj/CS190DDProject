# %% [markdown]
# CS190DD Part 1b:

# %%
import numpy as np

# %%
data = np.load("part1b.npz")

# %%
data.files
# Out:
# ['N', 'Lc', 'Ic_0', 'gamma', 'L_validation', 'L_test', 'betas_validation']

# %%
# exploring the data in part1b.npz
print("N:\n", data['N'],"\n")
print("gamma:\n", data['gamma'],"\n")
print("Lc:\n", data['Lc'],"\n")                              #length = 20 where each row is a new day
print("Ic_0:\n", data['Ic_0'],"\n")                          #length = 20
print("L_validation:\n", data['L_validation'],"\n")          #part1
print("L_test:\n", data['L_test'],"\n")                      #part 2/then predict for 100
print("betas_validation:\n", data['betas_validation'],"\n")  #part 1
# Out:
# N:
#  50000.0
#
# gamma:
#  0.07142857142857142
#
# Lc:
#  [0.3 0.4 0.7 1. ]
#
# Ic_0:
#  [[47 90 51 65]
#  [82 31 64 86]
#  [30 66 39 47]
#  [59 26 77 38]
#  [20 63 70 15]
#  [35 31 78 11]
#  [50 55 93 26]
#  [17 89 65 25]
#  [70 27 66 97]
#  [20 18 32 31]
#  [76 13 61 15]
#  [86 48 36 89]
#  [96 15 44 71]
#  [81 53 19 36]
#  [29 44 99 36]
#  [25 34 16 28]
#  [23 84 71 31]
#  [91 70 90 90]
#  [32 11 68 81]
#  [34 37 48 41]]
#
# L_validation:
#  [[  151.15723798   157.09236032   166.0663423    175.26894184
#     187.12271809   200.29536627   207.19011153   220.23944915
#     235.52590645   247.09469931   263.51055631   281.18896107
#     304.53407513   316.7776232    337.4146583    359.08603642
#     376.95873111   410.63777058   432.23666001   466.32640805]
#  [  168.20103748   175.31698233   184.41546073   191.23318015
#     200.38958258   212.84378649   222.09570163   237.44506788
#     251.13497681   263.20329764   281.12505942   299.02683147
# ...

# %%
# to whatever the dimensions of gridsearch comes out to be
# observed time series is already available in L_validation
L_validation = data['L_validation']
# L_validation = L_validation.reshape()
Ic_0 = data['Ic_0']
N = data['N']
gamma = data['gamma']

# %%
beta_t = np.linspace(0,1,21)
# dIc_dt and dR_dt will be the same for all compartments
dIc_dt = 0
dR_dt = 0

# %%
# will get predicted time series from gridsearch
# varies for each social vulnerability (every 5 leaf nodes = 1 social vulnerability)
# insert gridsearch here:

# %%
# comparison with the predicted and observed

# %%
# after two sets of data are available, for the 16 beta values, compare with the betas_validation file
B_0 = 0
dS0_dt = 0

# %%
# beta will be different for each comorbidity compartment whereas Lc and Rc will be the 
# same for different nodes
from sklearn.model_selection import ParameterGrid
